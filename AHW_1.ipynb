# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

plt.rcParams['font.size']=14
plt.rcParams['figure.figsize']=(12,8)

# %%
df = pd.read_csv('fire_nrt_V1_96617.csv')

# %%
df
# Out:
#         latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0      -42.69706  147.70634       333.6  0.57   0.43  2019-10-01       336
# 1      -42.26889  147.31104       336.2  0.39   0.44  2019-10-01       336
# 2      -40.85202  145.38068       327.9  0.46   0.47  2019-10-01       336
# 3      -42.39329  147.47144       346.9  0.38   0.43  2019-10-01       336
# 4      -42.69701  147.70584       334.1  0.56   0.43  2019-10-01       336
# ...          ...        ...         ...   ...    ...         ...       ...
# 956252 -32.66628  122.15253       306.9  0.39   0.44  2020-01-11      1630
# 956253 -32.58616  123.39582       299.0  0.51   0.41  2020-01-11      1630
# 956254 -33.37853  115.94735       309.7  0.40   0.60  2020-01-11      1630
# 956255 -33.21827  115.75078       300.2  0.49   0.65  2020-01-11      1806
# 956256 -33.22012  115.75043       300.3  0.49   0.65  2020-01-11      1806
#
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
sns.kdeplot(df.latitude)
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='Density'>

# %%
sns.kdeplot(df.latitude ,shade=True)
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='Density'>

# %% [markdown]
# ## TASK 1 : Density Plot

# %% [markdown]
# ### Task 1.1: Plot the longitude vs latitude several ways within a single figure (each in its own axes):

# %% [markdown]
# #### 1) Using the matplotlib defaults.

# %%
sns.histplot(y=df.latitude , x=df.longitude)
plt.show()

# %%
sns.scatterplot(data=df,y=df.latitude , x=df.longitude ,color='k')
plt.show()

# %% [markdown]
# #### 2) Adjusting alpha and marker size to compensate for overplotting

# %%
sns.scatterplot(data=df ,x=df.longitude, y=df.latitude , hue= df.daynight , style=df.daynight)
plt.show()

# %%
sns.scatterplot(data=df ,x=df.longitude, y=df.latitude,hue=df.confidence,palette='plasma')
plt.show()

# %% [markdown]
# #### 3) Using a hexbin plot.

# %%
plt.figure(figsize=(15,10))
plt.hexbin(x=df.longitude, y=df.latitude , bins='log' ,cmap=plt.cm.Greens)
plt.xlabel("longitude")
plt.ylabel("latitude")
plt.colorbar()

# %% [markdown]
# #### 4) Subsampling the dataset

# %%
subsample_data =df.sample(frac=0.05)

# %%
subsample_data
# Out:
#         latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 649632 -32.75140  151.00130       335.7  0.39   0.36  2019-12-20      1500
# 483346 -15.07281  125.08351       332.1  0.42   0.61  2019-12-07       430
# 103879 -11.76519  130.78140       331.1  0.55   0.68  2019-10-22       536
# 494358 -42.15578  147.96454       330.5  0.38   0.36  2019-12-08       400
# 158459 -31.29804  123.74285       306.5  0.63   0.54  2019-11-05      1724
# ...          ...        ...         ...   ...    ...         ...       ...
# 906879 -37.20690  149.49736       347.4  0.53   0.42  2020-01-04      1518
# 642967 -25.25116  149.14549       367.0  0.38   0.36  2019-12-20       342
# 200539 -27.82782  152.35533       355.3  0.56   0.43  2019-11-09       312
# 24018  -15.81211  144.46448       331.1  0.39   0.36  2019-10-06       354
# 48881  -14.11552  133.46860       337.6  0.79   0.78  2019-10-12       342
#
# ...

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
subsample_data =df.sample(frac=0.05)
sns.scatterplot(data=subsample_data ,x=subsample_data.longitude, y=subsample_data.latitude ,color='r' ,alpha=0.20)
plt.title("5% Data")

plt.subplot(2,2,2)
subsample_data =df.sample(frac=0.10)
sns.scatterplot(data=subsample_data ,x=subsample_data.longitude, y=subsample_data.latitude ,color='b' ,alpha=0.30,hue=df.daynight)
plt.title("10% Data")

plt.subplot(2,2,3)
subsample_data =df.sample(frac=0.15)
sns.scatterplot(data=subsample_data ,x=subsample_data.longitude, y=subsample_data.latitude ,color='g',alpha=0.40)
plt.title("15% Data")

plt.subplot(2,2,4)
subsample_data =df.sample(frac=0.20)
sns.scatterplot(data=subsample_data ,x=subsample_data.longitude, y=subsample_data.latitude ,color='k' ,alpha=0.10)
plt.title("20% Data")
# Out:
# Text(0.5, 1.0, '20% Data')

# %% [markdown]
# ### Task 1.2 : In what areas are most of the anomalies (measurements) located?

# %% [raw]
# Here , We can say that most of the data are located  in the right-bottom corner side  and top side of this graph.

# %% [markdown]
# ## TASK 2 : Visualizing class membership

# %% [markdown]
# #### Visualize the distribution of Brightness temperature I-4 as a histogram (with appropriate settings). Let’s assume we are certain of a fire if the value of temperature I-4 is saturated as visible from the histogram.

# %% [markdown]
# #### Task 2.1 : Do a small multiples plot of whether the brightness is saturated, i.e. do one plot of lat vs long for those points with brightness saturated and a separate for those who are not (within the same figure on separate axes). You can pick any of the methods from 1.1 that you find most suitable. Can you spot differences in the distributions?

# %%
df.head(1)
# Out:
#    latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0 -42.69706  147.70634       333.6  0.57   0.43  2019-10-01       336
#
#   satellite instrument confidence version  bright_ti5  frp daynight
# 0         N      VIIRS          n  1.0NRT       293.4  4.0        D

# %%
sns.histplot(df['bright_ti4'] , kde=True ,bins=30)
# Out:
# <AxesSubplot:xlabel='bright_ti4', ylabel='Count'>

# %%
max_sat = df.bright_ti4.max()

# %%
max_sat
# Out:
# 367.0

# %%
Highsat = df[df['bright_ti4'] >= max_sat]

# %%
Highsat
# Out:
#         latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 43     -22.41233  150.68094       367.0  0.42   0.38  2019-10-01       342
# 52     -19.94326  147.91037       367.0  0.38   0.36  2019-10-01       342
# 60     -26.20142  146.65320       367.0  0.43   0.38  2019-10-01       342
# 87     -22.50325  150.71536       367.0  0.42   0.38  2019-10-01       342
# 102    -18.32221  142.46642       367.0  0.55   0.43  2019-10-01       342
# ...          ...        ...         ...   ...    ...         ...       ...
# 954996 -35.62225  148.51337       367.0  0.47   0.40  2020-01-11      1448
# 955816 -36.35929  147.72372       367.0  0.49   0.40  2020-01-11      1448
# 955866 -36.73418  146.58713       367.0  0.54   0.42  2020-01-11      1448
# 955877 -36.73524  146.58754       367.0  0.54   0.42  2020-01-11      1448
# 955879 -36.73130  146.58841       367.0  0.54   0.42  2020-01-11      1448
#
# ...

# %%
Lowsat = df[df['bright_ti4'] < max_sat]

# %%
Lowsat
# Out:
#         latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0      -42.69706  147.70634       333.6  0.57   0.43  2019-10-01       336
# 1      -42.26889  147.31104       336.2  0.39   0.44  2019-10-01       336
# 2      -40.85202  145.38068       327.9  0.46   0.47  2019-10-01       336
# 3      -42.39329  147.47144       346.9  0.38   0.43  2019-10-01       336
# 4      -42.69701  147.70584       334.1  0.56   0.43  2019-10-01       336
# ...          ...        ...         ...   ...    ...         ...       ...
# 956252 -32.66628  122.15253       306.9  0.39   0.44  2020-01-11      1630
# 956253 -32.58616  123.39582       299.0  0.51   0.41  2020-01-11      1630
# 956254 -33.37853  115.94735       309.7  0.40   0.60  2020-01-11      1630
# 956255 -33.21827  115.75078       300.2  0.49   0.65  2020-01-11      1806
# 956256 -33.22012  115.75043       300.3  0.49   0.65  2020-01-11      1806
#
# ...

# %%
plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
sns.scatterplot(data=Highsat ,y=Highsat['latitude'] , x=Highsat['longitude'] ,color='g')

plt.subplot(2,2,2)
sns.scatterplot(data=Lowsat, y=Lowsat['latitude'] , x=Lowsat['longitude'] ,color='b')
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# #### Task 2.2 : Plot both groups in the same axes with different colors. Try changing the order of plotting the two classes (i.e. draw the saturated first then the non-saturated or the other way around). Make sure to include a legend. How does that impact the result?

# %%
sns.scatterplot(data=Highsat ,y=Highsat['latitude'] , x=Highsat['longitude'] ,color='b' , alpha=0.50)
sns.scatterplot(data=Lowsat, y=Lowsat['latitude'] , x=Lowsat['longitude'] ,color='r' , alpha=0.05)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# #### Task 2.3 : Can you find a better way to compare the two distributions?

# %%
# We can use heatmap also for two distributions.
